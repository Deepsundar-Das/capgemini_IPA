# %% [markdown]
# Data Analysis

# %%
import pandas as pd

# %%
s=pd.Series({'a':1,'b':2})

# %%
print(s.values)
print(s.size)
print(s.dtype)
print(s.mean())
# Out:
# [1 2]
# 2
# int64
# 1.5

# %%
print(s.std())
print(s.value_counts())
pd.DataFrame([1,2],[3,4])
# Out:
# 0.7071067811865476
# 1    1
# 2    1
# Name: count, dtype: int64
#    0
# 3  1
# 4  2

# %%
pd.DataFrame({'a':[1,2],'b':[3,6]})
# Out:
#    a  b
# 0  1  3
# 1  2  6

# %%
df = pd.read_csv("WineQT.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("WineQT.csv")
#       2 df.head
#
# File ~/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head(-1141)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 298             6.4             0.670         0.08             2.1      0.045
# 1142            5.9             0.645         0.12             2.0      0.075
# 474            11.3             0.340         0.45             2.0      0.082
# 776             8.4             0.340         0.42             2.1      0.072
# 322             8.9             0.590         0.39             2.3      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 298                  19.0                  48.0  0.99490  3.49       0.49
# 1142                 32.0                  44.0  0.99547  3.57       0.71
# 474                   6.0                  15.0  0.99880  2.94       0.66
# 776                  23.0                  36.0  0.99392  3.11       0.78
# 322                   5.0                  22.0  0.99860  3.37       0.58
#
#       alcohol  quality    Id
# ...

# %%
df.sample(5, ignore_index=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            9.0              0.58         0.25             2.0      0.104
# 1           12.0              0.39         0.66             3.0      0.093
# 2            7.8              0.41         0.68             1.7      0.467
# 3            7.1              0.43         0.42             5.5      0.071
# 4            7.3              0.51         0.18             2.1      0.070
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  8.0                  21.0  0.99769  3.27       0.72
# 1                 12.0                  30.0  0.99960  3.18       0.63
# 2                 18.0                  69.0  0.99730  3.08       1.31
# 3                 28.0                 128.0  0.99730  3.42       0.71
# 4                 12.0                  28.0  0.99768  3.52       0.73
#
#    alcohol  quality    Id
# 0      9.6        5  1227
# 1     10.8        7   407
# ...

# %%
print(df.ndim)
print(df.size)
df.info()
# Out:
# 2
# 14859
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df['fixed acidity'].dtype
# Out:
# dtype('float64')

# %%
# df.select_dtypes(exclude='float').columns
                # or
df.select_dtypes(include='int').columns
# Out:
# Index(['quality', 'Id'], dtype='object')

# %%
# indexing and slicing
df.iloc[0:10,0:4]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar
# 0            7.4              0.70         0.00             1.9
# 1            7.8              0.88         0.00             2.6
# 2            7.8              0.76         0.04             2.3
# 3           11.2              0.28         0.56             1.9
# 4            7.4              0.70         0.00             1.9
# 5            7.4              0.66         0.00             1.8
# 6            7.9              0.60         0.06             1.6
# 7            7.3              0.65         0.00             1.2
# 8            7.8              0.58         0.02             2.0
# 9            6.7              0.58         0.08             1.8

# %%
df['fixed acidity'][0]
# Out:
# np.float64(7.4)

# %%
df.iat[3,11]
# Out:
# np.int64(6)

# %%
# Missing values
df.notnull().sum()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
df.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.fillna(90)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# duplicate values
print(df.duplicated().count())

# drop duplicate datas
print(df.drop_duplicates(inplace=True))
# Out:
# 1143
# None

# %%
df.sort_values(by='alcohol')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 388            14.3              0.31         0.74             1.8      0.075
# 368            10.4              0.61         0.49             2.1      0.200
# 1023           10.0              0.38         0.38             1.6      0.169
# 263             7.9              0.24         0.40             1.6      0.056
# 1051            9.9              0.50         0.50            13.8      0.205
# ...             ...               ...          ...             ...        ...
# 589             4.9              0.42         0.00             2.1      0.048
# 419             5.0              0.42         0.24             2.0      0.060
# 98              5.2              0.34         0.00             1.8      0.050
# 96              5.2              0.34         0.00             1.8      0.050
# 462            15.9              0.36         0.65             7.5      0.096
#
# ...

# %%
df.sample(5).sort_index()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 48             8.0             0.705         0.05             1.9      0.074
# 176            7.1             0.600         0.00             1.8      0.074
# 641            6.1             0.560         0.00             2.2      0.079
# 871            7.8             0.815         0.01             2.6      0.074
# 931            8.0             1.180         0.21             1.9      0.083
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 48                   8.0                  19.0  0.99620  3.34       0.95
# 176                 16.0                  34.0  0.99720  3.47       0.70
# 641                  6.0                   9.0  0.99480  3.59       0.54
# 871                 48.0                  90.0  0.99621  3.38       0.62
# 931                 14.0                  41.0  0.99532  3.34       0.47
#
#      alcohol  quality    Id
# 48      10.5        6    69
# ...

# %%
df.sample(3, ignore_index=True,).sort_index(ascending=False)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2            7.6              0.79         0.21             2.3      0.087
# 1            7.6              0.41         0.14             3.0      0.087
# 0            7.3              0.33         0.47             2.1      0.077
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                 21.0                  68.0   0.9955  3.12       0.44
# 1                 21.0                  43.0   0.9964  3.32       0.57
# 0                  5.0                  11.0   0.9958  3.33       0.53
#
#    alcohol  quality    Id
# 2      9.2        5  1304
# 1     10.5        6   632
# 0     10.3        6   150

# %%
df[df['quality'] > 5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 13              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1138            6.3              0.51         0.13             2.3      0.076
# 1139            6.8              0.62         0.08             1.9      0.068
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
df.alcohol *= 1.10
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0    10.34        5   0
# 1    10.78        5   1
# ...

# %%
df.to_csv('wine.csv', index=False)

# %%
import math as m
df['quality_label'] = df['quality'].map({
    3:'very bad',
    4:'bad',
    5:'good',
    6:'very good',
    7:'Nice',
    8:'Exellent'
})
