# %%
try:
    a = eval(input("enter a number"))
    b = eval(input("enter another number"))
    print(a/b)
except ZeroDivisionError:
    print("division by zero is not allowed")
# Out:
# division by zero is not allowed

# %%
def safe_div():
    try:
        a = int(input("enter value of a"))
        b = int(input("enter value of b"))
        print(a/b)
    except Exception as e:
        print("something went wrong, ",e)

safe_div()
# Out:
# something went wrong,  invalid literal for int() with base 10: 'jdfk'

# %%
production = int(input("enter production count"))
if production < 0:
    raise ValueError("negative porduction is not possible")
else:
    print("production count : ", production)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 production = int(input("enter production count"))
#       2 if production < 0:
# ----> 3     raise ValueError("negative porduction is not possible")
#       4 else:
#       5     print("production count : ", production)
#
# ValueError: negative porduction is not possible

# %%
class AgeError(Exception):
    pass
age  = int(input("enter a age :"))
if age < 18:
    raise AgeError("age must be 18 or above")
else:
    print("eligible")
# Out:
# eligible

# %%
s1 = input("enter string1")
s2 = input("enter string2")
assert len(s1) == len(s2),"Length is different"
print("Length is same")
